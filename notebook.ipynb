# %%
import matplotlib.pyplot as plt 
from Maze import generate_maze, maze_to_array

# %%
width = 10
height = 10
param_straight = 0.3
param_cycle = 0.05

maze = generate_maze(width, height, param_straight, param_cycle, 4)
array = maze_to_array(maze)

# %%
# cmap = plt.cm.get_cmap("gray", 2)  # 2 discrete colors

# plt.imshow(array, cmap=cmap, vmin=-1, vmax=0)
# plt.axis("off")      
# plt.gca().invert_yaxis() # Top-left is (0,0)
# plt.tight_layout()
# plt.show()

# %%
# Creates a popup window in which can be drawn
# %matplotlib qt
from ACORenderer import ACORenderer
from ACO import ACO

start = (1, 1)
goal = (array.shape[0] - 2, array.shape[1] - 2)

ants = 1
pheromones = 5.0
evaporation = 0.5
initialisation = 0.2
random_path_chance = 0.1

optimizer = ACO(array.copy(), start, goal, ants, pheromones, evaporation, initialisation, random_path_chance)
renderer = ACORenderer(optimizer)
renderer.show()

# after window closes
final_maze = renderer.get_maze()
# Out:
# Running next iteration
# 0
# Traceback (most recent call last):
#   File "c:\Users\jaspe\Documents\Hobby\Coding_Projects\ACOMaze\venv\Lib\site-packages\matplotlib\cbook.py", line 361, in process
#     func(*args, **kwargs)
#   File "c:\Users\jaspe\Documents\Hobby\Coding_Projects\ACOMaze\ACORenderer.py", line 87, in _on_key_press
#     self.optimiser.next_iteration()
#   File "c:\Users\jaspe\Documents\Hobby\Coding_Projects\ACOMaze\ACO.py", line 45, in next_iteration
#     paths = self.__find_paths()
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\jaspe\Documents\Hobby\Coding_Projects\ACOMaze\ACO.py", line 75, in __find_paths
#     next_pos = path.pop()
#                ^^^^^^^^^^
# IndexError: pop from empty list
